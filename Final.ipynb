# %%
# -*- coding: utf-8 -*-
"""
Created on Mon Nov 15 17:16:43 2021

@author: Daniel Katusele
"""

from dolfin import *
import numpy as np
import math
import os
from mshr import *
from time import *

# Start time
st_time = time()

mesh = Mesh()
mvc = MeshValueCollection("size_t", mesh, mesh.topology().dim())
with XDMFFile("mesh3_V4.xdmf") as infile:
    infile.read(mesh)

# Geometric parameters
th = 0.2    # Thickness
rad = 1.35   # Radius to applied voltage
offset = 5.0


# Define Space
M = FunctionSpace(mesh, 'CG', 1)
V = VectorFunctionSpace(mesh, 'CG', 1)
T = TensorFunctionSpace(mesh, 'CG', 1)

W1 = VectorElement("CG", mesh.ufl_cell(), 2)
W2 = FiniteElement("CG", mesh.ufl_cell(), 1)
W = FunctionSpace(mesh, MixedElement([W1, W2]))
u_ = TrialFunction(W)
u, p = split(u_)
v_ = TestFunction(W)
v, q = split(v_)

phi, psi = TrialFunction(M), TestFunction(M)

phi_o, w = Function(M), Function(W)
phi_n, w2 = Function(M), Function(W)





# Mark boundary subdomians
tol = 1e-5
boundary_markers = MeshFunction('size_t', mesh, mesh.topology().dim()-1, 0)

boundary_markers.set_all(0)

def Dirichlet(x):
    return near(x[0], 0.0, tol) and near(x[1], 0.0, tol) and near(x[2], 0.0, tol)

class BoundarySide(SubDomain):
    def inside(self, x, on_boundary):
        r = math.sqrt(x[0]**2 + x[1]**2)
        return near(r, 1.5, 0.005) and on_boundary

class BoundaryTB(SubDomain):
    def inside(self, x, on_boundary):
        return (near(x[2], 0.0, tol) or near(x[2], th, tol)) and on_boundary

# The first sector (0 - 45 deg)
class BoundaryTop1(SubDomain):
    def inside(self, x, on_boundary):
        r = math.sqrt(x[0]**2 + x[1]**2)
        alpha = math.atan2(x[1],x[0])*180/math.pi
        if alpha < 0.0:
            alpha = alpha + 360.0
        return r >= rad and near(x[2], th, tol) and alpha > 0.0 + offset + tol and  alpha < 45.0 - offset - tol and on_boundary

# The 2nd sector (45 - 90 deg)
class BoundaryTop2(SubDomain):
    def inside(self, x, on_boundary):
        r = math.sqrt(x[0]**2 + x[1]**2)
        alpha = math.atan2(x[1],x[0])*180/math.pi
        if alpha < 0.0:
            alpha = alpha + 360.0
        return r >= rad and near(x[2], th, tol) and alpha > 45.0 + offset + tol and  alpha < 90.0 - offset - tol and on_boundary

# The sector (90 - 135 deg)
class BoundaryTop3(SubDomain):
    def inside(self, x, on_boundary):
        r = math.sqrt(x[0]**2 + x[1]**2)
        alpha = math.atan2(x[1],x[0])*180/math.pi
        if alpha < 0.0:
            alpha = alpha + 360.0
        return r >= rad and near(x[2], th, tol) and alpha > 90.0 + offset + tol and  alpha < 135.0 - offset - tol and on_boundary

# The sector (135 - 180 deg)
class BoundaryTop4(SubDomain):
    def inside(self, x, on_boundary):
        r = math.sqrt(x[0]**2 + x[1]**2)
        alpha = math.atan2(x[1],x[0])*180/math.pi
        if alpha < 0.0:
            alpha = alpha + 360.0
        return r >= rad and near(x[2], th, tol) and alpha > 135.0 + offset + tol and  alpha < 180.0 - offset - tol and on_boundary

# The first sector (180 - 225 deg)
class BoundaryTop5(SubDomain):
    def inside(self, x, on_boundary):
        r = math.sqrt(x[0]**2 + x[1]**2)
        alpha = math.atan2(x[1],x[0])*180/math.pi
        if alpha < 0.0:
            alpha = alpha + 360.0
        return r >= rad and near(x[2], th, tol) and alpha > 180.0 + offset + tol and  alpha < 225.0 - offset - tol and on_boundary

# The 2nd sector (225 - 270 deg)
class BoundaryTop6(SubDomain):
    def inside(self, x, on_boundary):
        r = math.sqrt(x[0]**2 + x[1]**2)
        alpha = math.atan2(x[1],x[0])*180/math.pi
        if alpha < 0.0:
            alpha = alpha + 360.0
        return r >= rad and near(x[2], th, tol) and alpha > 225.0 + offset + tol and  alpha < 270.0 - offset - 2*tol and on_boundary

# The first sector (270 - 315 deg)
class BoundaryTop7(SubDomain):
    def inside(self, x, on_boundary):
        r = math.sqrt(x[0]**2 + x[1]**2)
        alpha = math.atan2(x[1],x[0])*180/math.pi
        if alpha < 0.0:
            alpha = alpha + 360.0
        return r >= rad and near(x[2], th, tol) and alpha > 270.0 + offset + tol and  alpha < 315.0 - offset - 2*tol and on_boundary

# The 2nd sector (315 - 360 deg)
class BoundaryTop8(SubDomain):
    def inside(self, x, on_boundary):
        r = math.sqrt(x[0]**2 + x[1]**2)
        alpha = math.atan2(x[1],x[0])*180/math.pi
        if alpha < 0.0:
            alpha = alpha + 360.0
        return r >= rad and near(x[2], th, tol) and alpha > 315.0 + offset + tol and  alpha < 360.0 - offset - tol and on_boundary
 
# The sector (0 - 180 deg)
class BoundaryBot1(SubDomain):
    def inside(self, x, on_boundary):
        r = math.sqrt(x[0]**2 + x[1]**2)
        alpha = math.atan2(x[1],x[0])*180/math.pi
        if alpha < 0.0:
            alpha = alpha + 360.0
        return r >= rad and near(x[2], 0.0, tol) and alpha > 0.0 + offset + tol and alpha < 45 - offset - tol and on_boundary

# The sector (45 - 90 deg)
class BoundaryBot2(SubDomain):
    def inside(self, x, on_boundary):
        r = math.sqrt(x[0]**2 + x[1]**2)
        alpha = math.atan2(x[1],x[0])*180/math.pi
        if alpha < 0.0:
            alpha = alpha + 360.0
        return r >= rad and near(x[2], 0.0, tol) and alpha > 45.0 + offset + tol and alpha < 90.0 - offset - tol and on_boundary

        # The sector (90 - 135 deg)
class BoundaryBot3(SubDomain):
    def inside(self, x, on_boundary):
        r = math.sqrt(x[0]**2 + x[1]**2)
        alpha = math.atan2(x[1],x[0])*180/math.pi
        if alpha < 0.0:
            alpha = alpha + 360.0
        return r >= rad and near(x[2], 0.0, tol) and alpha > 90.0 + offset + tol and alpha < 135.0 - offset - tol and on_boundary

# The sector (135 - 180 deg)
class BoundaryBot4(SubDomain):
    def inside(self, x, on_boundary):
        r = math.sqrt(x[0]**2 + x[1]**2)
        alpha = math.atan2(x[1],x[0])*180/math.pi
        if alpha < 0.0:
            alpha = alpha + 360.0
        return r >= rad and near(x[2], 0.0, tol) and alpha > 135.0 + offset + tol and alpha < 180.0 - offset - tol and on_boundary

# The sector (180 - 225 deg)
class BoundaryBot5(SubDomain):
    def inside(self, x, on_boundary):
        r = math.sqrt(x[0]**2 + x[1]**2)
        alpha = math.atan2(x[1],x[0])*180/math.pi
        if alpha < 0.0:
            alpha = alpha + 360.0
        return r >= rad and near(x[2], 0.0, tol) and alpha > 180.0 + offset + tol and alpha < 225.0 - offset - tol and on_boundary

# The sector (225 - 270 deg)
class BoundaryBot6(SubDomain):
    def inside(self, x, on_boundary):
        r = math.sqrt(x[0]**2 + x[1]**2)
        alpha = math.atan2(x[1],x[0])*180/math.pi
        if alpha < 0.0:
            alpha = alpha + 360.0
        return r >= rad and near(x[2], 0.0, tol) and alpha > 225.0 + offset + tol and alpha < 270.0 - offset - tol and on_boundary

        # The sector (270 - 315 deg)
class BoundaryBot7(SubDomain):
    def inside(self, x, on_boundary):
        r = math.sqrt(x[0]**2 + x[1]**2)
        alpha = math.atan2(x[1],x[0])*180/math.pi
        if alpha < 0.0:
            alpha = alpha + 360.0
        return r >= rad and near(x[2], 0.0, tol) and alpha > 270.0 + offset + tol and alpha < 315.0 - offset - tol and on_boundary

# The sector (315 - 360 deg)
class BoundaryBot8(SubDomain):
    def inside(self, x, on_boundary):
        r = math.sqrt(x[0]**2 + x[1]**2)
        alpha = math.atan2(x[1],x[0])*180/math.pi
        if alpha < 0.0:
            alpha = alpha + 360.0
        return r >= rad and near(x[2], 0.0, tol) and alpha > 315.0 + offset + tol and alpha < 360.0 - offset - tol and on_boundary


b_top = BoundaryTB()
b_top.mark(boundary_markers, 1)

b_top2 = BoundaryTop2()
b_top2.mark(boundary_markers, 2)

b_top3 = BoundaryTop3()
b_top3.mark(boundary_markers, 3)

b_top4 = BoundaryTop4()
b_top4.mark(boundary_markers, 4)

b_top5 = BoundaryTop5()
b_top5.mark(boundary_markers, 5)

b_top6 = BoundaryTop6()
b_top6.mark(boundary_markers, 6)

b_top7 = BoundaryTop7()
b_top7.mark(boundary_markers, 7)

b_top8 = BoundaryTop8()
b_top8.mark(boundary_markers, 8)

b_bot = BoundaryBot1()
b_bot.mark(boundary_markers, 9)

b_bot2 = BoundaryBot2()
b_bot2.mark(boundary_markers, 10)

b_bot3 = BoundaryBot3()
b_bot3.mark(boundary_markers, 11)

b_bot4 = BoundaryBot4()
b_bot4.mark(boundary_markers, 12)

b_bot5 = BoundaryBot5()
b_bot5.mark(boundary_markers, 13)

b_bot6 = BoundaryBot6()
b_bot6.mark(boundary_markers, 14)

b_bot7 = BoundaryBot7()
b_bot7.mark(boundary_markers, 15)

b_bot8 = BoundaryBot8()
b_bot8.mark(boundary_markers, 16)

b_bot8 = BoundaryTop1()
b_bot8.mark(boundary_markers, 17)

File("Boundary_C.pvd") << boundary_markers
# Collect Dirichlet conditions
bcs2 = []
bcs1 = []
u_D = Constant((0.0, 0.0, 0.0))  # Zero displacement
volt1 = Expression('volt', degree= 1, volt=0.0)
volt2 = Expression('volt', degree= 1, volt=0.0)
volt3 = Expression('volt', degree= 1, volt=0.0)
volt4 = Expression('volt', degree= 1, volt=0.0)
volt5 = Expression('volt', degree= 1, volt=0.0)
volt6 = Expression('volt', degree= 1, volt=0.0)
volt7 = Expression('volt', degree= 1, volt=0.0)
volt8 = Expression('volt', degree= 1, volt=0.0)
# VOLT2 = Expression('volt', degree= 1, volt=0.0001)
# VOLT3 = Expression('-volt', degree= 1, volt=0.0001)
bcs2.append(DirichletBC(W.sub(0), u_D, Dirichlet, method="pointwise"))


bcs1.append(DirichletBC(M, volt1, boundary_markers, 17))
bcs1.append(DirichletBC(M, volt2, boundary_markers, 2))
bcs1.append(DirichletBC(M, volt3, boundary_markers, 3))
bcs1.append(DirichletBC(M, volt4, boundary_markers, 4))
bcs1.append(DirichletBC(M, volt5, boundary_markers, 5))
bcs1.append(DirichletBC(M, volt6, boundary_markers, 6))
bcs1.append(DirichletBC(M, volt7, boundary_markers, 7))
bcs1.append(DirichletBC(M, volt8, boundary_markers, 8))

def energy(phi, u, p):
    # Kinematics
    I = Identity(u.geometric_dimension())  # Identity tensor
    F = I + grad(u)  # Deformation gradient
    C = F.T * F  # Right Cauchy-Green tensor

    # Invariants of deformation tensors
    Ic = tr(C)
    IIc = 0.5 * (tr(C) * tr(C) - tr(C * C))

    FinvT = inv(F).T
    E = -grad(phi)

    # Energy
    engy = 0.5 * ((Ic - 3.0) + gamma*(IIc - 3.0))*dx + 0.5 * det(F) * dot(FinvT * E, FinvT * E)*dx - p * (det(F) - 1.0)*dx

    return engy, F


# Redefine boundary integration measure
ds = Measure('ds', domain=mesh, subdomain_data=boundary_markers)

# Constant variables
t0 = Constant((0.0, 0.0, 0.0))   # Zero traction
normal = FacetNormal(mesh)
incDLoad = 0.6                   # Load increament
DLoad = 4.5                 # Final load
Voltge = 5.e-3

incAngle = math.pi/100.0                   # Voltage increament
MaxAngle = math.pi                   # Voltage load

# Elasticity parameters
gamma = Constant(0.3)


# Define output file 
fName = input("Enter file name: ")
print('File name: ', fName + '.xdmf')
fileName = fName + '.xdmf'
fileName2 = fName + '.h5'
# try:
#     os.remove(fileName)
#     os.remove(fileName2)
# except OSError:
#     pass
fileResults = XDMFFile(fileName)
fileResults.parameters["flush_output"] = True
fileResults.parameters["functions_share_mesh"] = True

print('File name= ', fileName)
print('-------------------')
# Initialize iteration parameters
frame = 0         # Frame tracking parameter
j = 0.01          # Applied load at the start of the loop
k = 0.001         # Applied voltage at the start of the loop
l = 0
i=1               # Iteration tracking parameter


# Apply dead load incrementally
while j <= DLoad:
    print("---------- Dead Load Iteration: %i ------------" % (i))
    
    if j > 3.5 and j < 3.85:
        incDLoad = 0.05
    elif j >= 3.85 and j < 3.88:
        incDLoad = 0.01
        volt1.volt = Voltge*math.sin(l - 3*math.pi/4)
        volt2.volt = Voltge*math.sin(l - math.pi/2)
        volt3.volt = Voltge*math.sin(l - math.pi/4)
        volt4.volt = Voltge*math.sin(l)
        volt5.volt = Voltge*math.sin(l + math.pi/4)
        volt6.volt = Voltge*math.sin(l + math.pi/2)
        volt7.volt = Voltge*math.sin(l + 3*math.pi/4)
        volt8.volt = Voltge*math.sin(l + math.pi)
    elif j > 3.88 and j < 3.902:
        incDLoad = 0.001
    elif j > 3.902:
        incDLoad = 0.1


    print('Load: ', j)
    # Traction
    t = Constant(j) * normal
    t2 = Constant(j) * normal


    # Define variational problem
    '''
    p_disp = NonlinearVariationalProblem(Frm2, w2, bcs2, J=J)
    solver_d = NonlinearVariationalSolver(p_disp)


    prm = solver_d.parameters
    prm["nonlinear_solver"] = "newton"  # default. could be "snes"
    prm["newton_solver"]['linear_solver'] = 'petsc'
    prm["newton_solver"]["absolute_tolerance"] = 1E-9
    prm["newton_solver"]["relative_tolerance"] = 1.0E-5
    prm["newton_solver"]["maximum_iterations"] = 100
    prm["newton_solver"]["relaxation_parameter"] = 1.0
    prm["newton_solver"]['krylov_solver']['nonzero_initial_guess'] = True


    #solver_d.solve()
    '''
    err = 1
    iter = 1
    tolce = 1.e-3
    while err > tolce:
        # Total energy
        u_o, p_o = split(w)

        [Engy, F] = energy(phi_n, u_o, p_o)

        # Laplace equation
        Frm = det(F) * inner(inv(F).T * grad(phi), inv(F).T * grad(psi))*dx 

        p_phi = LinearVariationalProblem(lhs(Frm), rhs(Frm), phi_n, bcs1)
        solver_p = LinearVariationalSolver(p_phi)
        solver_p.solve()

        # Mechanical equation
        T_engy = Engy - dot(t,u_o)*ds(0) - dot(t0,u_o)*(ds(2) + ds(3)+ ds(4) + ds(5) + ds(6) + ds(7) \
                + ds(8) + ds(9) + ds(10) + ds(11) + ds(12) + ds(13) + ds(14) + ds(15) + ds(16) + ds(17)) \
            - det(F) * dot( inv(F.T*F) * grad(phi_n), normal) * phi_n * (ds(2) + ds(3)+ ds(4) + ds(5) + ds(6) + ds(7) \
                + ds(8) + ds(9) + ds(10) + ds(11) + ds(12) + ds(13) + ds(14) + ds(15) + ds(16) + ds(17))

        Frm2 = derivative(T_engy, w, v_)

        solve(Frm2 == 0, w, bcs2, solver_parameters={"newton_solver":
                                                {'relative_tolerance': 1.0e-5,'absolute_tolerance': 1.0e-9, 'maximum_iterations': 100,
                                                'relaxation_parameter': 1.0, 'linear_solver': 'petsc'}},
            form_compiler_parameters = {'cpp_optimize': True})


        err_u = errornorm(w2.sub(0), w.sub(0), norm_type = 'l2',mesh = mesh)
        err_phi = errornorm(phi_n, phi_o, norm_type = 'l2',mesh = mesh)
        err = max(err_u,err_phi)

        w2.assign(w)
        phi_o.assign(phi_n)

        iter = iter + 1
        print('Error: ', err)

    # Post-processing

    u_n, p_n = split(w2)
    I = Identity(u_n.geometric_dimension())  # Identity tensor
    F_p = I + grad(u_n)  # Deformation gradient
    C = F_p.T * F_p  # Right Cauchy-Green tensor

    # Invariants of deformation tensors
    Ic = tr(C)

    FinvT = inv(F_p).T

    E = -grad(phi_o)
    
    C_stress = (1.0/det(F_p)) * ((1.0 + gamma*Ic) * F_p * F_p.T - gamma * F_p * F_p.T * F_p * F_p.T) - p_n * I \
            + (outer(FinvT * E, FinvT * E) - 0.5 * dot(FinvT * E, FinvT * E) * I)

    
    if i % 1.0 == 0.0:
        frame += 1
        disp = Function(V, name='Displacement')
        disp.assign(project(u_n, V))
        fileResults.write(disp, frame)

        lgr = Function(M, name='Lgr Mult')
        lgr.assign(project(p_n, M))
        fileResults.write(lgr, frame)

        voltage = Function(M, name='Voltage')
        voltage.assign(project(phi_n, M))
        fileResults.write(voltage, frame)

        defgrad = Function(T, name='DefGrad')
        defgrad.assign(project(F_p, T))
        fileResults.write(defgrad, frame)

        el_f = Function(V, name='Electric field')
        el_f.assign(project(-grad(phi_n), V))
        fileResults.write(el_f, frame)

    j = j + incDLoad

    if j > DLoad:
        DLoad = j - incDLoad
    w.assign(w)
    w2.assign(w2)
    i = i + 1

print('Time: ', strftime("%H:%M:%S", gmtime(time() - st_time))) 

# Apply voltage incremetally
i = 1

while l <= MaxAngle:
    print("---------- Voltage Iteration: %i ------------" % (i))
    
    #parameters['linear_algebra_backend'] = 'PETSc'
    parameters["form_compiler"]["cpp_optimize"] = True
    parameters["form_compiler"]["quadrature_rule"] = 'auto'
    #parameters["form_compiler"]["quadrature_degree"] = 6
    # Traction
    t = Constant(DLoad) * normal
    t2 = Constant(DLoad) * normal

    
    volt1.volt = Voltge*math.sin(l - 3*math.pi/4)
    volt2.volt = Voltge*math.sin(l - math.pi/2)
    volt3.volt = Voltge*math.sin(l - math.pi/4)
    volt4.volt = Voltge*math.sin(l)
    volt5.volt = Voltge*math.sin(l + math.pi/4)
    volt6.volt = Voltge*math.sin(l + math.pi/2)
    volt7.volt = Voltge*math.sin(l + 3*math.pi/4)
    volt8.volt = Voltge*math.sin(l + math.pi)

    err = 1
    iter = 1
    tolce = 1.e-4
    while err > tolce:
        # Total energy
        u_o, p_o = split(w)

        [Engy, F] = energy(phi_n, u_o, p_o)

        # Laplace equation
        Frm = det(F) * inner(inv(F).T * grad(phi), inv(F).T * grad(psi))*dx 

        p_phi = LinearVariationalProblem(lhs(Frm), rhs(Frm), phi_n, bcs1)
        solver_p = LinearVariationalSolver(p_phi)
        solver_p.solve()

        # Mechanical equation
        T_engy = Engy - dot(t,u_o)*ds(0) - dot(t0,u_o)*(ds(2) + ds(3)+ ds(4) + ds(5) + ds(6) + ds(7) \
                + ds(8) + ds(9) + ds(10) + ds(11) + ds(12) + ds(13) + ds(14) + ds(15) + ds(16) + ds(17)) \
            - dot(det(F) * inv(F.T*F) * grad(phi_n), normal) * phi_n * (ds(2) + ds(3)+ ds(4) + ds(5) + ds(6) + ds(7) \
                + ds(8) + ds(9) + ds(10) + ds(11) + ds(12) + ds(13) + ds(14) + ds(15) + ds(16) + ds(17))

        Frm2 = derivative(T_engy, w, v_)

        solve(Frm2 == 0, w, bcs2, solver_parameters={"newton_solver":
                                                {'relative_tolerance': 1.0e-6,'absolute_tolerance': 1.0e-9, 'maximum_iterations': 100,
                                                'relaxation_parameter': 1.0, 'linear_solver': 'petsc'}},
            form_compiler_parameters = {'cpp_optimize': True})

        u_o, p_o = split(w)
        u_n, p_n = split(w2)

        err_u = errornorm(w2.sub(0), w.sub(0), norm_type = 'l2', mesh = mesh)
        err_phi = errornorm(phi_n, phi_o, norm_type = 'l2', mesh = mesh)
        err = max(err_u,err_phi)

        w2.assign(w)
        phi_o.assign(phi_n)

        iter = iter + 1
        print('Error: ', err)

     # Post-processing

    u_n, p_n = split(w2)
    I = Identity(u_n.geometric_dimension())  # Identity tensor
    F_p = I + grad(u_n)  # Deformation gradient
    C = F_p.T * F_p  # Right Cauchy-Green tensor

    # Invariants of deformation tensors
    Ic = tr(C)

    FinvT = inv(F_p).T

    E = -grad(phi_o)
    
    C_stress = (1.0/det(F_p)) * ((1.0 + gamma*Ic) * F_p * F_p.T - gamma * F_p * F_p.T * F_p * F_p.T) - p_n * I \
            + (outer(FinvT * E, FinvT * E) - 0.5 * dot(FinvT * E, FinvT * E) * I)

    if i % 1.0 == 0.0:
        frame += 1
        u_n, p_n = split(w2)
        disp = Function(V, name='Displacement')
        disp.assign(project(u_n, V))
        fileResults.write(disp, frame)

        lgr = Function(M, name='Lgr Mult')
        lgr.assign(project(p_n, M))
        fileResults.write(lgr, frame)

        voltage = Function(M, name='Voltage')
        voltage.assign(project(phi_n, M))
        fileResults.write(voltage, frame)

        defgrad = Function(T, name='DefGrad')
        defgrad.assign(project(F_p, T))
        fileResults.write(defgrad, frame)

        el_f = Function(V, name='Electric field')
        el_f.assign(project(-grad(phi_n), V))
        fileResults.write(el_f, frame)

    l = l + incAngle

    w.assign(w)
    w2.assign(w2)
    i = i + 1


print('Initial Volume: ', 1.4137)

print('Time: ', strftime("%H:%M:%S", gmtime(time() - st_time)))

print('Successfully completed')
# Out:
# File name:  Electromechanical3.xdmf
# File name=  Electromechanical3.xdmf
# -------------------
# ---------- Dead Load Iteration: 1 ------------
# Load:  0.01
# Solving linear variational problem.
# No Jacobian form specified for nonlinear variational problem.
# Differentiating residual form F to obtain Jacobian J = F'.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 3.509e-01 (tol = 1.000e-09) r (rel) = 1.000e+00 (tol = 1.000e-05)
#   Newton iteration 1: r (abs) = 2.208e-03 (tol = 1.000e-09) r (rel) = 6.293e-03 (tol = 1.000e-05)
#   Newton iteration 2: r (abs) = 3.256e-06 (tol = 1.000e-09) r (rel) = 9.280e-06 (tol = 1.000e-05)
#   Newton solver finished in 2 iterations and 2 linear solver iterations.
# *** Warning: Degree of exact solution may be inadequate for accurate result in errornorm.
# *** Warning: Degree of exact solution may be inadequate for accurate result in errornorm.
# Error:  0.0016577521952976654
# Solving linear variational problem.
# No Jacobian form specified for nonlinear variational problem.
# Differentiating residual form F to obtain Jacobian J = F'.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 3.256e-06 (tol = 1.000e-09) r (rel) = 1.000e+00 (tol = 1.000e-05)
#   Newton iteration 1: r (abs) = 1.645e-12 (tol = 1.000e-09) r (rel) = 5.052e-07 (tol = 1.000e-05)
#   Newton solver finished in 1 iterations and 1 linear solver iterations.
# *** Warning: Degree of exact solution may be inadequate for accurate result in errornorm.
# *** Warning: Degree of exact solution may be inadequate for accurate result in errornorm.
# Error:  1.6956175936493402e-06
# ---------- Dead Load Iteration: 2 ------------
# Load:  0.61
# Solving linear variational problem.
# No Jacobian form specified for nonlinear variational problem.
# Differentiating residual form F to obtain Jacobian J = F'.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 5.046e-02 (tol = 1.000e-09) r (rel) = 1.000e+00 (tol = 1.000e-05)
#   Newton iteration 1: r (abs) = 8.882e-03 (tol = 1.000e-09) r (rel) = 1.760e-01 (tol = 1.000e-05)
#   Newton iteration 2: r (abs) = 1.194e-04 (tol = 1.000e-09) r (rel) = 2.366e-03 (tol = 1.000e-05)
#   Newton iteration 3: r (abs) = 1.237e-08 (tol = 1.000e-09) r (rel) = 2.451e-07 (tol = 1.000e-05)
#   Newton solver finished in 3 iterations and 3 linear solver iterations.
# *** Warning: Degree of exact solution may be inadequate for accurate result in errornorm.
# *** Warning: Degree of exact solution may be inadequate for accurate result in errornorm.
# Error:  0.1167621802410026
# Solving linear variational problem.
# No Jacobian form specified for nonlinear variational problem.
# Differentiating residual form F to obtain Jacobian J = F'.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 1.237e-08 (tol = 1.000e-09) r (rel) = 1.000e+00 (tol = 1.000e-05)
#   Newton iteration 1: r (abs) = 4.836e-16 (tol = 1.000e-09) r (rel) = 3.909e-08 (tol = 1.000e-05)
#   Newton solver finished in 1 iterations and 1 linear solver iterations.
# *** Warning: Degree of exact solution may be inadequate for accurate result in errornorm.
# *** Warning: Degree of exact solution may be inadequate for accurate result in errornorm.
# Error:  9.131352187262999e-09
# ---------- Dead Load Iteration: 3 ------------
# Load:  1.21
# Solving linear variational problem.
# No Jacobian form specified for nonlinear variational problem.
# Differentiating residual form F to obtain Jacobian J = F'.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 5.046e-02 (tol = 1.000e-09) r (rel) = 1.000e+00 (tol = 1.000e-05)
#   Newton iteration 1: r (abs) = 1.192e-02 (tol = 1.000e-09) r (rel) = 2.362e-01 (tol = 1.000e-05)
#   Newton iteration 2: r (abs) = 2.747e-04 (tol = 1.000e-09) r (rel) = 5.444e-03 (tol = 1.000e-05)
#   Newton iteration 3: r (abs) = 8.069e-08 (tol = 1.000e-09) r (rel) = 1.599e-06 (tol = 1.000e-05)
#   Newton solver finished in 3 iterations and 3 linear solver iterations.
# *** Warning: Degree of exact solution may be inadequate for accurate result in errornorm.
# *** Warning: Degree of exact solution may be inadequate for accurate result in errornorm.
# Error:  0.15671782256925873
# Solving linear variational problem.
# No Jacobian form specified for nonlinear variational problem.
# Differentiating residual form F to obtain Jacobian J = F'.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 8.069e-08 (tol = 1.000e-09) r (rel) = 1.000e+00 (tol = 1.000e-05)
#   Newton iteration 1: r (abs) = 5.446e-15 (tol = 1.000e-09) r (rel) = 6.749e-08 (tol = 1.000e-05)
#   Newton solver finished in 1 iterations and 1 linear solver iterations.
# *** Warning: Degree of exact solution may be inadequate for accurate result in errornorm.
# *** Warning: Degree of exact solution may be inadequate for accurate result in errornorm.
# Error:  6.829664491865331e-08
# ---------- Dead Load Iteration: 4 ------------
# Load:  1.81
# Solving linear variational problem.
# No Jacobian form specified for nonlinear variational problem.
# Differentiating residual form F to obtain Jacobian J = F'.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 5.046e-02 (tol = 1.000e-09) r (rel) = 1.000e+00 (tol = 1.000e-05)
#   Newton iteration 1: r (abs) = 1.361e-02 (tol = 1.000e-09) r (rel) = 2.697e-01 (tol = 1.000e-05)
#   Newton iteration 2: r (abs) = 2.944e-04 (tol = 1.000e-09) r (rel) = 5.835e-03 (tol = 1.000e-05)
#   Newton iteration 3: r (abs) = 3.495e-08 (tol = 1.000e-09) r (rel) = 6.926e-07 (tol = 1.000e-05)
#   Newton solver finished in 3 iterations and 3 linear solver iterations.
# *** Warning: Degree of exact solution may be inadequate for accurate result in errornorm.
# *** Warning: Degree of exact solution may be inadequate for accurate result in errornorm.
# Error:  0.1931975369756987
# Solving linear variational problem.
# No Jacobian form specified for nonlinear variational problem.
# Differentiating residual form F to obtain Jacobian J = F'.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 3.495e-08 (tol = 1.000e-09) r (rel) = 1.000e+00 (tol = 1.000e-05)
#   Newton iteration 1: r (abs) = 4.743e-15 (tol = 1.000e-09) r (rel) = 1.357e-07 (tol = 1.000e-05)
#   Newton solver finished in 1 iterations and 1 linear solver iterations.
# *** Warning: Degree of exact solution may be inadequate for accurate result in errornorm.
# *** Warning: Degree of exact solution may be inadequate for accurate result in errornorm.
# Error:  1.4566813366094612e-07
# ---------- Dead Load Iteration: 5 ------------
# Load:  2.41
# Solving linear variational problem.
# No Jacobian form specified for nonlinear variational problem.
# Differentiating residual form F to obtain Jacobian J = F'.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 5.046e-02 (tol = 1.000e-09) r (rel) = 1.000e+00 (tol = 1.000e-05)
#   Newton iteration 1: r (abs) = 1.161e-02 (tol = 1.000e-09) r (rel) = 2.302e-01 (tol = 1.000e-05)
#   Newton iteration 2: r (abs) = 9.873e-05 (tol = 1.000e-09) r (rel) = 1.957e-03 (tol = 1.000e-05)
#   Newton iteration 3: r (abs) = 3.593e-08 (tol = 1.000e-09) r (rel) = 7.121e-07 (tol = 1.000e-05)
#   Newton solver finished in 3 iterations and 3 linear solver iterations.
# *** Warning: Degree of exact solution may be inadequate for accurate result in errornorm.
# *** Warning: Degree of exact solution may be inadequate for accurate result in errornorm.
# Error:  0.20765403137429483
# Solving linear variational problem.
# No Jacobian form specified for nonlinear variational problem.
# Differentiating residual form F to obtain Jacobian J = F'.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 3.593e-08 (tol = 1.000e-09) r (rel) = 1.000e+00 (tol = 1.000e-05)
#   Newton iteration 1: r (abs) = 2.514e-15 (tol = 1.000e-09) r (rel) = 6.997e-08 (tol = 1.000e-05)
#   Newton solver finished in 1 iterations and 1 linear solver iterations.
# *** Warning: Degree of exact solution may be inadequate for accurate result in errornorm.
# *** Warning: Degree of exact solution may be inadequate for accurate result in errornorm.
# Error:  1.7100290480945427e-08
# ---------- Dead Load Iteration: 6 ------------
# Load:  3.0100000000000002
# Solving linear variational problem.
# No Jacobian form specified for nonlinear variational problem.
# Differentiating residual form F to obtain Jacobian J = F'.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 5.046e-02 (tol = 1.000e-09) r (rel) = 1.000e+00 (tol = 1.000e-05)
#   Newton iteration 1: r (abs) = 7.948e-03 (tol = 1.000e-09) r (rel) = 1.575e-01 (tol = 1.000e-05)
#   Newton iteration 2: r (abs) = 6.992e-05 (tol = 1.000e-09) r (rel) = 1.386e-03 (tol = 1.000e-05)
#   Newton iteration 3: r (abs) = 9.361e-09 (tol = 1.000e-09) r (rel) = 1.855e-07 (tol = 1.000e-05)
#   Newton solver finished in 3 iterations and 3 linear solver iterations.
# *** Warning: Degree of exact solution may be inadequate for accurate result in errornorm.
# *** Warning: Degree of exact solution may be inadequate for accurate result in errornorm.
# Error:  0.2010869612382231
# Solving linear variational problem.
# No Jacobian form specified for nonlinear variational problem.
# Differentiating residual form F to obtain Jacobian J = F'.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 9.361e-09 (tol = 1.000e-09) r (rel) = 1.000e+00 (tol = 1.000e-05)
#   Newton iteration 1: r (abs) = 2.996e-15 (tol = 1.000e-09) r (rel) = 3.200e-07 (tol = 1.000e-05)
#   Newton solver finished in 1 iterations and 1 linear solver iterations.
# *** Warning: Degree of exact solution may be inadequate for accurate result in errornorm.
# *** Warning: Degree of exact solution may be inadequate for accurate result in errornorm.
# Error:  1.3417355552351025e-08
# ---------- Dead Load Iteration: 7 ------------
# Load:  3.6100000000000003
# Solving linear variational problem.
# No Jacobian form specified for nonlinear variational problem.
# Differentiating residual form F to obtain Jacobian J = F'.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 5.046e-02 (tol = 1.000e-09) r (rel) = 1.000e+00 (tol = 1.000e-05)
#   Newton iteration 1: r (abs) = 5.302e-03 (tol = 1.000e-09) r (rel) = 1.051e-01 (tol = 1.000e-05)
#   Newton iteration 2: r (abs) = 4.717e-05 (tol = 1.000e-09) r (rel) = 9.348e-04 (tol = 1.000e-05)
#   Newton iteration 3: r (abs) = 2.798e-09 (tol = 1.000e-09) r (rel) = 5.544e-08 (tol = 1.000e-05)
#   Newton solver finished in 3 iterations and 3 linear solver iterations.
# *** Warning: Degree of exact solution may be inadequate for accurate result in errornorm.
# *** Warning: Degree of exact solution may be inadequate for accurate result in errornorm.
# Error:  0.18603521289936345
# Solving linear variational problem.
# No Jacobian form specified for nonlinear variational problem.
# Differentiating residual form F to obtain Jacobian J = F'.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 2.798e-09 (tol = 1.000e-09) r (rel) = 1.000e+00 (tol = 1.000e-05)
#   Newton iteration 1: r (abs) = 3.875e-15 (tol = 1.000e-09) r (rel) = 1.385e-06 (tol = 1.000e-05)
#   Newton solver finished in 1 iterations and 1 linear solver iterations.
# *** Warning: Degree of exact solution may be inadequate for accurate result in errornorm.
# *** Warning: Degree of exact solution may be inadequate for accurate result in errornorm.
# Error:  7.961796773391125e-10
# ---------- Dead Load Iteration: 8 ------------
# Load:  3.66
# Solving linear variational problem.
# No Jacobian form specified for nonlinear variational problem.
# Differentiating residual form F to obtain Jacobian J = F'.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 4.205e-03 (tol = 1.000e-09) r (rel) = 1.000e+00 (tol = 1.000e-05)
#   Newton iteration 1: r (abs) = 2.587e-05 (tol = 1.000e-09) r (rel) = 6.153e-03 (tol = 1.000e-05)
#   Newton iteration 2: r (abs) = 1.424e-09 (tol = 1.000e-09) r (rel) = 3.385e-07 (tol = 1.000e-05)
#   Newton solver finished in 2 iterations and 2 linear solver iterations.
# *** Warning: Degree of exact solution may be inadequate for accurate result in errornorm.
# *** Warning: Degree of exact solution may be inadequate for accurate result in errornorm.
# Error:  0.014769563874206986
# Solving linear variational problem.
# No Jacobian form specified for nonlinear variational problem.
# Differentiating residual form F to obtain Jacobian J = F'.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 1.424e-09 (tol = 1.000e-09) r (rel) = 1.000e+00 (tol = 1.000e-05)
#   Newton iteration 1: r (abs) = 3.965e-15 (tol = 1.000e-09) r (rel) = 2.785e-06 (tol = 1.000e-05)
#   Newton solver finished in 1 iterations and 1 linear solver iterations.
# *** Warning: Degree of exact solution may be inadequate for accurate result in errornorm.
# *** Warning: Degree of exact solution may be inadequate for accurate result in errornorm.
# Error:  1.0744835170740458e-09
# ---------- Dead Load Iteration: 9 ------------
# Load:  3.71
# Solving linear variational problem.
# No Jacobian form specified for nonlinear variational problem.
# Differentiating residual form F to obtain Jacobian J = F'.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 4.205e-03 (tol = 1.000e-09) r (rel) = 1.000e+00 (tol = 1.000e-05)
#   Newton iteration 1: r (abs) = 2.530e-05 (tol = 1.000e-09) r (rel) = 6.016e-03 (tol = 1.000e-05)
#   Newton iteration 2: r (abs) = 1.353e-09 (tol = 1.000e-09) r (rel) = 3.217e-07 (tol = 1.000e-05)
#   Newton solver finished in 2 iterations and 2 linear solver iterations.
# *** Warning: Degree of exact solution may be inadequate for accurate result in errornorm.
# *** Warning: Degree of exact solution may be inadequate for accurate result in errornorm.
# Error:  0.014658509923765507
# Solving linear variational problem.
# No Jacobian form specified for nonlinear variational problem.
# Differentiating residual form F to obtain Jacobian J = F'.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 1.353e-09 (tol = 1.000e-09) r (rel) = 1.000e+00 (tol = 1.000e-05)
#   Newton iteration 1: r (abs) = 4.010e-15 (tol = 1.000e-09) r (rel) = 2.964e-06 (tol = 1.000e-05)
#   Newton solver finished in 1 iterations and 1 linear solver iterations.
# *** Warning: Degree of exact solution may be inadequate for accurate result in errornorm.
# *** Warning: Degree of exact solution may be inadequate for accurate result in errornorm.
# Error:  9.642700697580084e-10
# ---------- Dead Load Iteration: 10 ------------
# Load:  3.76
# Solving linear variational problem.
# No Jacobian form specified for nonlinear variational problem.
# Differentiating residual form F to obtain Jacobian J = F'.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 4.205e-03 (tol = 1.000e-09) r (rel) = 1.000e+00 (tol = 1.000e-05)
#   Newton iteration 1: r (abs) = 2.475e-05 (tol = 1.000e-09) r (rel) = 5.886e-03 (tol = 1.000e-05)
#   Newton iteration 2: r (abs) = 1.286e-09 (tol = 1.000e-09) r (rel) = 3.059e-07 (tol = 1.000e-05)
#   Newton solver finished in 2 iterations and 2 linear solver iterations.
# *** Warning: Degree of exact solution may be inadequate for accurate result in errornorm.
# *** Warning: Degree of exact solution may be inadequate for accurate result in errornorm.
# Error:  0.014548251399128895
# Solving linear variational problem.
# No Jacobian form specified for nonlinear variational problem.
# Differentiating residual form F to obtain Jacobian J = F'.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 1.286e-09 (tol = 1.000e-09) r (rel) = 1.000e+00 (tol = 1.000e-05)
#   Newton iteration 1: r (abs) = 4.058e-15 (tol = 1.000e-09) r (rel) = 3.155e-06 (tol = 1.000e-05)
#   Newton solver finished in 1 iterations and 1 linear solver iterations.
# *** Warning: Degree of exact solution may be inadequate for accurate result in errornorm.
# *** Warning: Degree of exact solution may be inadequate for accurate result in errornorm.
# Error:  1.0923524210196656e-09
# ---------- Dead Load Iteration: 11 ------------
# Load:  3.8099999999999996
# Solving linear variational problem.
# No Jacobian form specified for nonlinear variational problem.
# Differentiating residual form F to obtain Jacobian J = F'.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 4.205e-03 (tol = 1.000e-09) r (rel) = 1.000e+00 (tol = 1.000e-05)
#   Newton iteration 1: r (abs) = 2.423e-05 (tol = 1.000e-09) r (rel) = 5.762e-03 (tol = 1.000e-05)
#   Newton iteration 2: r (abs) = 1.229e-09 (tol = 1.000e-09) r (rel) = 2.922e-07 (tol = 1.000e-05)
#   Newton solver finished in 2 iterations and 2 linear solver iterations.
# *** Warning: Degree of exact solution may be inadequate for accurate result in errornorm.
# *** Warning: Degree of exact solution may be inadequate for accurate result in errornorm.
# Error:  0.014438859125848491
# Solving linear variational problem.
# No Jacobian form specified for nonlinear variational problem.
# Differentiating residual form F to obtain Jacobian J = F'.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 1.229e-09 (tol = 1.000e-09) r (rel) = 1.000e+00 (tol = 1.000e-05)
#   Newton iteration 1: r (abs) = 4.115e-15 (tol = 1.000e-09) r (rel) = 3.349e-06 (tol = 1.000e-05)
#   Newton solver finished in 1 iterations and 1 linear solver iterations.
# *** Warning: Degree of exact solution may be inadequate for accurate result in errornorm.
# *** Warning: Degree of exact solution may be inadequate for accurate result in errornorm.
# Error:  3.2726843548307518e-09
# ---------- Dead Load Iteration: 12 ------------
# Load:  3.8599999999999994
# Solving linear variational problem.
# No Jacobian form specified for nonlinear variational problem.
# Differentiating residual form F to obtain Jacobian J = F'.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 4.207e-03 (tol = 1.000e-09) r (rel) = 1.000e+00 (tol = 1.000e-05)
#   Newton iteration 1: r (abs) = 2.371e-05 (tol = 1.000e-09) r (rel) = 5.635e-03 (tol = 1.000e-05)
#   Newton iteration 2: r (abs) = 2.545e-09 (tol = 1.000e-09) r (rel) = 6.050e-07 (tol = 1.000e-05)
#   Newton solver finished in 2 iterations and 2 linear solver iterations.
# *** Warning: Degree of exact solution may be inadequate for accurate result in errornorm.
# *** Warning: Degree of exact solution may be inadequate for accurate result in errornorm.
# Error:  0.014331053632384239
# Solving linear variational problem.
# No Jacobian form specified for nonlinear variational problem.
# Differentiating residual form F to obtain Jacobian J = F'.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 1.598e-06 (tol = 1.000e-09) r (rel) = 1.000e+00 (tol = 1.000e-05)
#   Newton iteration 1: r (abs) = 1.913e-12 (tol = 1.000e-09) r (rel) = 1.198e-06 (tol = 1.000e-05)
#   Newton solver finished in 1 iterations and 1 linear solver iterations.
# *** Warning: Degree of exact solution may be inadequate for accurate result in errornorm.
# *** Warning: Degree of exact solution may be inadequate for accurate result in errornorm.
# Error:  3.8156852093211087e-07
# ---------- Dead Load Iteration: 13 ------------
# Load:  3.869999999999999
# Solving linear variational problem.
# No Jacobian form specified for nonlinear variational problem.
# Differentiating residual form F to obtain Jacobian J = F'.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 8.410e-04 (tol = 1.000e-09) r (rel) = 1.000e+00 (tol = 1.000e-05)
#   Newton iteration 1: r (abs) = 9.276e-07 (tol = 1.000e-09) r (rel) = 1.103e-03 (tol = 1.000e-05)
#   Newton iteration 2: r (abs) = 4.325e-11 (tol = 1.000e-09) r (rel) = 5.143e-08 (tol = 1.000e-05)
#   Newton solver finished in 2 iterations and 2 linear solver iterations.
# *** Warning: Degree of exact solution may be inadequate for accurate result in errornorm.
# *** Warning: Degree of exact solution may be inadequate for accurate result in errornorm.
# Error:  0.0028533417800945785
# Solving linear variational problem.
# No Jacobian form specified for nonlinear variational problem.
# Differentiating residual form F to obtain Jacobian J = F'.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 3.122e-07 (tol = 1.000e-09) r (rel) = 1.000e+00 (tol = 1.000e-05)
#   Newton iteration 1: r (abs) = 7.321e-14 (tol = 1.000e-09) r (rel) = 2.345e-07 (tol = 1.000e-05)
#   Newton solver finished in 1 iterations and 1 linear solver iterations.
# *** Warning: Degree of exact solution may be inadequate for accurate result in errornorm.
# *** Warning: Degree of exact solution may be inadequate for accurate result in errornorm.
# Error:  7.541794027404101e-08
# ---------- Dead Load Iteration: 14 ------------
# Load:  3.879999999999999
# Solving linear variational problem.
# No Jacobian form specified for nonlinear variational problem.
# Differentiating residual form F to obtain Jacobian J = F'.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 8.410e-04 (tol = 1.000e-09) r (rel) = 1.000e+00 (tol = 1.000e-05)
#   Newton iteration 1: r (abs) = 9.235e-07 (tol = 1.000e-09) r (rel) = 1.098e-03 (tol = 1.000e-05)
#   Newton iteration 2: r (abs) = 2.752e-10 (tol = 1.000e-09) r (rel) = 3.272e-07 (tol = 1.000e-05)
#   Newton solver finished in 2 iterations and 2 linear solver iterations.
# *** Warning: Degree of exact solution may be inadequate for accurate result in errornorm.
# *** Warning: Degree of exact solution may be inadequate for accurate result in errornorm.
# Error:  0.0028497478665755376
# Solving linear variational problem.
# No Jacobian form specified for nonlinear variational problem.
# Differentiating residual form F to obtain Jacobian J = F'.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 3.130e-07 (tol = 1.000e-09) r (rel) = 1.000e+00 (tol = 1.000e-05)
#   Newton iteration 1: r (abs) = 7.341e-14 (tol = 1.000e-09) r (rel) = 2.345e-07 (tol = 1.000e-05)
#   Newton solver finished in 1 iterations and 1 linear solver iterations.
# *** Warning: Degree of exact solution may be inadequate for accurate result in errornorm.
# *** Warning: Degree of exact solution may be inadequate for accurate result in errornorm.
# Error:  7.994390610798016e-08
# ---------- Dead Load Iteration: 15 ------------
# Load:  3.889999999999999
# Solving linear variational problem.
# No Jacobian form specified for nonlinear variational problem.
# Differentiating residual form F to obtain Jacobian J = F'.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 8.410e-04 (tol = 1.000e-09) r (rel) = 1.000e+00 (tol = 1.000e-05)
#   Newton iteration 1: r (abs) = 9.193e-07 (tol = 1.000e-09) r (rel) = 1.093e-03 (tol = 1.000e-05)
#   Newton iteration 2: r (abs) = 5.943e-09 (tol = 1.000e-09) r (rel) = 7.066e-06 (tol = 1.000e-05)
#   Newton solver finished in 2 iterations and 2 linear solver iterations.
# *** Warning: Degree of exact solution may be inadequate for accurate result in errornorm.
# *** Warning: Degree of exact solution may be inadequate for accurate result in errornorm.
# Error:  0.0028562929897043158
# Solving linear variational problem.
# No Jacobian form specified for nonlinear variational problem.
# Differentiating residual form F to obtain Jacobian J = F'.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 3.187e-07 (tol = 1.000e-09) r (rel) = 1.000e+00 (tol = 1.000e-05)
#   Newton iteration 1: r (abs) = 7.689e-14 (tol = 1.000e-09) r (rel) = 2.413e-07 (tol = 1.000e-05)
#   Newton solver finished in 1 iterations and 1 linear solver iterations.
# *** Warning: Degree of exact solution may be inadequate for accurate result in errornorm.
# *** Warning: Degree of exact solution may be inadequate for accurate result in errornorm.
# Error:  1.360984423577315e-07
# ---------- Dead Load Iteration: 16 ------------
# Load:  3.8909999999999987
# Solving linear variational problem.
# No Jacobian form specified for nonlinear variational problem.
# Differentiating residual form F to obtain Jacobian J = F'.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 8.410e-05 (tol = 1.000e-09) r (rel) = 1.000e+00 (tol = 1.000e-05)
#   Newton iteration 1: r (abs) = 9.355e-09 (tol = 1.000e-09) r (rel) = 1.112e-04 (tol = 1.000e-05)
#   Newton iteration 2: r (abs) = 1.702e-11 (tol = 1.000e-09) r (rel) = 2.024e-07 (tol = 1.000e-05)
#   Newton solver finished in 2 iterations and 2 linear solver iterations.
# *** Warning: Degree of exact solution may be inadequate for accurate result in errornorm.
# *** Warning: Degree of exact solution may be inadequate for accurate result in errornorm.
# Error:  0.0002924097748767084
# ---------- Dead Load Iteration: 17 ------------
# Load:  3.8919999999999986
# Solving linear variational problem.
# No Jacobian form specified for nonlinear variational problem.
# Differentiating residual form F to obtain Jacobian J = F'.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 8.410e-05 (tol = 1.000e-09) r (rel) = 1.000e+00 (tol = 1.000e-05)
#   Newton iteration 1: r (abs) = 9.561e-09 (tol = 1.000e-09) r (rel) = 1.137e-04 (tol = 1.000e-05)
#   Newton iteration 2: r (abs) = 3.865e-11 (tol = 1.000e-09) r (rel) = 4.596e-07 (tol = 1.000e-05)
#   Newton solver finished in 2 iterations and 2 linear solver iterations.
# *** Warning: Degree of exact solution may be inadequate for accurate result in errornorm.
# *** Warning: Degree of exact solution may be inadequate for accurate result in errornorm.
# Error:  0.0002990629769399441
# ---------- Dead Load Iteration: 18 ------------
# Load:  3.8929999999999985
# Solving linear variational problem.
# No Jacobian form specified for nonlinear variational problem.
# Differentiating residual form F to obtain Jacobian J = F'.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 8.410e-05 (tol = 1.000e-09) r (rel) = 1.000e+00 (tol = 1.000e-05)
#   Newton iteration 1: r (abs) = 1.008e-08 (tol = 1.000e-09) r (rel) = 1.199e-04 (tol = 1.000e-05)
#   Newton iteration 2: r (abs) = 1.010e-10 (tol = 1.000e-09) r (rel) = 1.201e-06 (tol = 1.000e-05)
#   Newton solver finished in 2 iterations and 2 linear solver iterations.
# *** Warning: Degree of exact solution may be inadequate for accurate result in errornorm.
# *** Warning: Degree of exact solution may be inadequate for accurate result in errornorm.
# Error:  0.000313933574693868
# ---------- Dead Load Iteration: 19 ------------
# Load:  3.8939999999999984
# Solving linear variational problem.
# No Jacobian form specified for nonlinear variational problem.
# Differentiating residual form F to obtain Jacobian J = F'.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 8.410e-05 (tol = 1.000e-09) r (rel) = 1.000e+00 (tol = 1.000e-05)
#   Newton iteration 1: r (abs) = 1.167e-08 (tol = 1.000e-09) r (rel) = 1.388e-04 (tol = 1.000e-05)
#   Newton iteration 2: r (abs) = 3.225e-10 (tol = 1.000e-09) r (rel) = 3.835e-06 (tol = 1.000e-05)
#   Newton solver finished in 2 iterations and 2 linear solver iterations.
# *** Warning: Degree of exact solution may be inadequate for accurate result in errornorm.
# *** Warning: Degree of exact solution may be inadequate for accurate result in errornorm.
# Error:  0.0003516631929132048
# ---------- Dead Load Iteration: 20 ------------
# Load:  3.8949999999999982
# Solving linear variational problem.
# No Jacobian form specified for nonlinear variational problem.
# Differentiating residual form F to obtain Jacobian J = F'.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 8.410e-05 (tol = 1.000e-09) r (rel) = 1.000e+00 (tol = 1.000e-05)
#   Newton iteration 1: r (abs) = 1.749e-08 (tol = 1.000e-09) r (rel) = 2.080e-04 (tol = 1.000e-05)
#   Newton iteration 2: r (abs) = 1.402e-09 (tol = 1.000e-09) r (rel) = 1.667e-05 (tol = 1.000e-05)
#   Newton iteration 3: r (abs) = 4.241e-15 (tol = 1.000e-09) r (rel) = 5.043e-11 (tol = 1.000e-05)
#   Newton solver finished in 3 iterations and 3 linear solver iterations.
# *** Warning: Degree of exact solution may be inadequate for accurate result in errornorm.
# *** Warning: Degree of exact solution may be inadequate for accurate result in errornorm.
# Error:  0.00046298470884397174
# ---------- Dead Load Iteration: 21 ------------
# Load:  3.895999999999998
# Solving linear variational problem.
# No Jacobian form specified for nonlinear variational problem.
# Differentiating residual form F to obtain Jacobian J = F'.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 8.410e-05 (tol = 1.000e-09) r (rel) = 1.000e+00 (tol = 1.000e-05)
#   Newton iteration 1: r (abs) = 4.303e-08 (tol = 1.000e-09) r (rel) = 5.116e-04 (tol = 1.000e-05)
#   Newton iteration 2: r (abs) = 1.060e-08 (tol = 1.000e-09) r (rel) = 1.261e-04 (tol = 1.000e-05)
#   Newton iteration 3: r (abs) = 8.840e-15 (tol = 1.000e-09) r (rel) = 1.051e-10 (tol = 1.000e-05)
#   Newton solver finished in 3 iterations and 3 linear solver iterations.
# *** Warning: Degree of exact solution may be inadequate for accurate result in errornorm.
# *** Warning: Degree of exact solution may be inadequate for accurate result in errornorm.
# Error:  0.0008654922124436819
# ---------- Dead Load Iteration: 22 ------------
# Load:  3.896999999999998
# Solving linear variational problem.
# No Jacobian form specified for nonlinear variational problem.
# Differentiating residual form F to obtain Jacobian J = F'.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 8.410e-05 (tol = 1.000e-09) r (rel) = 1.000e+00 (tol = 1.000e-05)
#   Newton iteration 1: r (abs) = 2.115e-07 (tol = 1.000e-09) r (rel) = 2.515e-03 (tol = 1.000e-05)
#   Newton iteration 2: r (abs) = 3.328e-07 (tol = 1.000e-09) r (rel) = 3.957e-03 (tol = 1.000e-05)
#   Newton iteration 3: r (abs) = 1.162e-10 (tol = 1.000e-09) r (rel) = 1.382e-06 (tol = 1.000e-05)
#   Newton solver finished in 3 iterations and 3 linear solver iterations.
# *** Warning: Degree of exact solution may be inadequate for accurate result in errornorm.
# *** Warning: Degree of exact solution may be inadequate for accurate result in errornorm.
# Error:  0.0034105050963993753
# Solving linear variational problem.
# No Jacobian form specified for nonlinear variational problem.
# Differentiating residual form F to obtain Jacobian J = F'.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 1.316e-07 (tol = 1.000e-09) r (rel) = 1.000e+00 (tol = 1.000e-05)
#   Newton iteration 1: r (abs) = 2.392e-11 (tol = 1.000e-09) r (rel) = 1.817e-04 (tol = 1.000e-05)
#   Newton solver finished in 1 iterations and 1 linear solver iterations.
# *** Warning: Degree of exact solution may be inadequate for accurate result in errornorm.
# *** Warning: Degree of exact solution may be inadequate for accurate result in errornorm.
# Error:  6.587452419157474e-06
# ---------- Dead Load Iteration: 23 ------------
# Load:  3.897999999999998
# Solving linear variational problem.
# No Jacobian form specified for nonlinear variational problem.
# Differentiating residual form F to obtain Jacobian J = F'.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 8.410e-05 (tol = 1.000e-09) r (rel) = 1.000e+00 (tol = 1.000e-05)
#   Newton iteration 1: r (abs) = 5.393e-06 (tol = 1.000e-09) r (rel) = 6.413e-02 (tol = 1.000e-05)
#   Newton iteration 2: r (abs) = 1.804e-04 (tol = 1.000e-09) r (rel) = 2.146e+00 (tol = 1.000e-05)
#   Newton iteration 3: r (abs) = 8.047e-06 (tol = 1.000e-09) r (rel) = 9.568e-02 (tol = 1.000e-05)
#   Newton iteration 4: r (abs) = 6.303e-06 (tol = 1.000e-09) r (rel) = 7.494e-02 (tol = 1.000e-05)
#   Newton iteration 5: r (abs) = 8.373e-06 (tol = 1.000e-09) r (rel) = 9.956e-02 (tol = 1.000e-05)
#   Newton iteration 6: r (abs) = 3.010e-06 (tol = 1.000e-09) r (rel) = 3.579e-02 (tol = 1.000e-05)
#   Newton iteration 7: r (abs) = 1.889e-07 (tol = 1.000e-09) r (rel) = 2.247e-03 (tol = 1.000e-05)
#   Newton iteration 8: r (abs) = 5.547e-09 (tol = 1.000e-09) r (rel) = 6.596e-05 (tol = 1.000e-05)
#   Newton iteration 9: r (abs) = 3.118e-12 (tol = 1.000e-09) r (rel) = 3.707e-08 (tol = 1.000e-05)
#   Newton solver finished in 9 iterations and 9 linear solver iterations.
# *** Warning: Degree of exact solution may be inadequate for accurate result in errornorm.
# *** Warning: Degree of exact solution may be inadequate for accurate result in errornorm.
# Error:  0.03216490454256773
# Solving linear variational problem.
# No Jacobian form specified for nonlinear variational problem.
# Differentiating residual form F to obtain Jacobian J = F'.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 8.472e-07 (tol = 1.000e-09) r (rel) = 1.000e+00 (tol = 1.000e-05)
#   Newton iteration 1: r (abs) = 5.624e-09 (tol = 1.000e-09) r (rel) = 6.637e-03 (tol = 1.000e-05)
#   Newton iteration 2: r (abs) = 2.692e-12 (tol = 1.000e-09) r (rel) = 3.177e-06 (tol = 1.000e-05)
#   Newton solver finished in 2 iterations and 2 linear solver iterations.
# *** Warning: Degree of exact solution may be inadequate for accurate result in errornorm.
# *** Warning: Degree of exact solution may be inadequate for accurate result in errornorm.
# Error:  0.00010490235931637833
# ---------- Dead Load Iteration: 24 ------------
# Load:  3.898999999999998
# Solving linear variational problem.
# No Jacobian form specified for nonlinear variational problem.
# Differentiating residual form F to obtain Jacobian J = F'.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 8.410e-05 (tol = 1.000e-09) r (rel) = 1.000e+00 (tol = 1.000e-05)
#   Newton iteration 1: r (abs) = 3.445e-04 (tol = 1.000e-09) r (rel) = 4.096e+00 (tol = 1.000e-05)
#   Newton iteration 2: r (abs) = 2.673e-05 (tol = 1.000e-09) r (rel) = 3.178e-01 (tol = 1.000e-05)
#   Newton iteration 3: r (abs) = 1.217e-05 (tol = 1.000e-09) r (rel) = 1.448e-01 (tol = 1.000e-05)
#   Newton iteration 4: r (abs) = 2.401e-06 (tol = 1.000e-09) r (rel) = 2.855e-02 (tol = 1.000e-05)
#   Newton iteration 5: r (abs) = 2.218e-07 (tol = 1.000e-09) r (rel) = 2.638e-03 (tol = 1.000e-05)
#   Newton iteration 6: r (abs) = 1.537e-08 (tol = 1.000e-09) r (rel) = 1.828e-04 (tol = 1.000e-05)
#   Newton iteration 7: r (abs) = 1.442e-11 (tol = 1.000e-09) r (rel) = 1.715e-07 (tol = 1.000e-05)
#   Newton solver finished in 7 iterations and 7 linear solver iterations.
# *** Warning: Degree of exact solution may be inadequate for accurate result in errornorm.
# *** Warning: Degree of exact solution may be inadequate for accurate result in errornorm.
# Error:  0.034151093345890844
# Solving linear variational problem.
# No Jacobian form specified for nonlinear variational problem.
# Differentiating residual form F to obtain Jacobian J = F'.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 9.713e-07 (tol = 1.000e-09) r (rel) = 1.000e+00 (tol = 1.000e-05)
#   Newton iteration 1: r (abs) = 4.344e-10 (tol = 1.000e-09) r (rel) = 4.473e-04 (tol = 1.000e-05)
#   Newton solver finished in 1 iterations and 1 linear solver iterations.
# *** Warning: Degree of exact solution may be inadequate for accurate result in errornorm.
# *** Warning: Degree of exact solution may be inadequate for accurate result in errornorm.
# Error:  3.7654930545213214e-05
# ---------- Dead Load Iteration: 25 ------------
# Load:  3.8999999999999977
# Solving linear variational problem.
# No Jacobian form specified for nonlinear variational problem.
# Differentiating residual form F to obtain Jacobian J = F'.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 8.410e-05 (tol = 1.000e-09) r (rel) = 1.000e+00 (tol = 1.000e-05)
#   Newton iteration 1: r (abs) = 3.310e-05 (tol = 1.000e-09) r (rel) = 3.936e-01 (tol = 1.000e-05)
#   Newton iteration 2: r (abs) = 6.170e-07 (tol = 1.000e-09) r (rel) = 7.337e-03 (tol = 1.000e-05)
#   Newton iteration 3: r (abs) = 5.867e-09 (tol = 1.000e-09) r (rel) = 6.976e-05 (tol = 1.000e-05)
#   Newton iteration 4: r (abs) = 4.549e-12 (tol = 1.000e-09) r (rel) = 5.409e-08 (tol = 1.000e-05)
#   Newton solver finished in 4 iterations and 4 linear solver iterations.
# *** Warning: Degree of exact solution may be inadequate for accurate result in errornorm.
# *** Warning: Degree of exact solution may be inadequate for accurate result in errornorm.
# Error:  0.019906614734703443
# Solving linear variational problem.
# No Jacobian form specified for nonlinear variational problem.
# Differentiating residual form F to obtain Jacobian J = F'.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 5.676e-07 (tol = 1.000e-09) r (rel) = 1.000e+00 (tol = 1.000e-05)
#   Newton iteration 1: r (abs) = 5.646e-11 (tol = 1.000e-09) r (rel) = 9.947e-05 (tol = 1.000e-05)
#   Newton solver finished in 1 iterations and 1 linear solver iterations.
# *** Warning: Degree of exact solution may be inadequate for accurate result in errornorm.
# *** Warning: Degree of exact solution may be inadequate for accurate result in errornorm.
# Error:  5.990415520951299e-06
# ---------- Dead Load Iteration: 26 ------------
# Load:  3.9009999999999976
# Solving linear variational problem.
# No Jacobian form specified for nonlinear variational problem.
# Differentiating residual form F to obtain Jacobian J = F'.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 8.410e-05 (tol = 1.000e-09) r (rel) = 1.000e+00 (tol = 1.000e-05)
#   Newton iteration 1: r (abs) = 1.827e-05 (tol = 1.000e-09) r (rel) = 2.172e-01 (tol = 1.000e-05)
#   Newton iteration 2: r (abs) = 1.429e-07 (tol = 1.000e-09) r (rel) = 1.699e-03 (tol = 1.000e-05)
#   Newton iteration 3: r (abs) = 2.103e-10 (tol = 1.000e-09) r (rel) = 2.501e-06 (tol = 1.000e-05)
#   Newton solver finished in 3 iterations and 3 linear solver iterations.
# *** Warning: Degree of exact solution may be inadequate for accurate result in errornorm.
# *** Warning: Degree of exact solution may be inadequate for accurate result in errornorm.
# Error:  0.015802729073015852
# Solving linear variational problem.
# No Jacobian form specified for nonlinear variational problem.
# Differentiating residual form F to obtain Jacobian J = F'.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 4.540e-07 (tol = 1.000e-09) r (rel) = 1.000e+00 (tol = 1.000e-05)
#   Newton iteration 1: r (abs) = 2.571e-11 (tol = 1.000e-09) r (rel) = 5.664e-05 (tol = 1.000e-05)
#   Newton solver finished in 1 iterations and 1 linear solver iterations.
# *** Warning: Degree of exact solution may be inadequate for accurate result in errornorm.
# *** Warning: Degree of exact solution may be inadequate for accurate result in errornorm.
# Error:  9.785215158069118e-06
# ---------- Dead Load Iteration: 27 ------------
# Load:  3.9019999999999975
# Solving linear variational problem.
# No Jacobian form specified for nonlinear variational problem.
# Differentiating residual form F to obtain Jacobian J = F'.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 8.410e-05 (tol = 1.000e-09) r (rel) = 1.000e+00 (tol = 1.000e-05)
#   Newton iteration 1: r (abs) = 1.268e-05 (tol = 1.000e-09) r (rel) = 1.508e-01 (tol = 1.000e-05)
#   Newton iteration 2: r (abs) = 5.408e-08 (tol = 1.000e-09) r (rel) = 6.431e-04 (tol = 1.000e-05)
#   Newton iteration 3: r (abs) = 3.046e-11 (tol = 1.000e-09) r (rel) = 3.622e-07 (tol = 1.000e-05)
#   Newton solver finished in 3 iterations and 3 linear solver iterations.
# *** Warning: Degree of exact solution may be inadequate for accurate result in errornorm.
# *** Warning: Degree of exact solution may be inadequate for accurate result in errornorm.
# Error:  0.013535174071988463
# Solving linear variational problem.
# No Jacobian form specified for nonlinear variational problem.
# Differentiating residual form F to obtain Jacobian J = F'.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 3.919e-07 (tol = 1.000e-09) r (rel) = 1.000e+00 (tol = 1.000e-05)
#   Newton iteration 1: r (abs) = 1.664e-11 (tol = 1.000e-09) r (rel) = 4.245e-05 (tol = 1.000e-05)
#   Newton solver finished in 1 iterations and 1 linear solver iterations.
# *** Warning: Degree of exact solution may be inadequate for accurate result in errornorm.
# *** Warning: Degree of exact solution may be inadequate for accurate result in errornorm.
# Error:  1.0881309218509626e-05
# ---------- Dead Load Iteration: 28 ------------
# Load:  3.9029999999999974
# Solving linear variational problem.
# No Jacobian form specified for nonlinear variational problem.
# Differentiating residual form F to obtain Jacobian J = F'.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 8.410e-05 (tol = 1.000e-09) r (rel) = 1.000e+00 (tol = 1.000e-05)
#   Newton iteration 1: r (abs) = 9.725e-06 (tol = 1.000e-09) r (rel) = 1.156e-01 (tol = 1.000e-05)
#   Newton iteration 2: r (abs) = 2.607e-08 (tol = 1.000e-09) r (rel) = 3.099e-04 (tol = 1.000e-05)
#   Newton iteration 3: r (abs) = 1.041e-11 (tol = 1.000e-09) r (rel) = 1.238e-07 (tol = 1.000e-05)
#   Newton solver finished in 3 iterations and 3 linear solver iterations.
# *** Warning: Degree of exact solution may be inadequate for accurate result in errornorm.
# *** Warning: Degree of exact solution may be inadequate for accurate result in errornorm.
# Error:  0.012037787288985297
# Solving linear variational problem.
# No Jacobian form specified for nonlinear variational problem.
# Differentiating residual form F to obtain Jacobian J = F'.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 3.512e-07 (tol = 1.000e-09) r (rel) = 1.000e+00 (tol = 1.000e-05)
#   Newton iteration 1: r (abs) = 1.317e-11 (tol = 1.000e-09) r (rel) = 3.749e-05 (tol = 1.000e-05)
#   Newton solver finished in 1 iterations and 1 linear solver iterations.
# *** Warning: Degree of exact solution may be inadequate for accurate result in errornorm.
# *** Warning: Degree of exact solution may be inadequate for accurate result in errornorm.
# Error:  1.1460955005843663e-05
# ---------- Dead Load Iteration: 29 ------------
# Load:  4.0029999999999974
# Solving linear variational problem.
# No Jacobian form specified for nonlinear variational problem.
# Differentiating residual form F to obtain Jacobian J = F'.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 8.410e-03 (tol = 1.000e-09) r (rel) = 1.000e+00 (tol = 1.000e-05)
#   Newton iteration 1: r (abs) = 8.413e-02 (tol = 1.000e-09) r (rel) = 1.000e+01 (tol = 1.000e-05)
#   Newton iteration 2: r (abs) = 6.304e-03 (tol = 1.000e-09) r (rel) = 7.495e-01 (tol = 1.000e-05)
#   Newton iteration 3: r (abs) = 5.558e-03 (tol = 1.000e-09) r (rel) = 6.609e-01 (tol = 1.000e-05)
#   Newton iteration 4: r (abs) = 1.193e-03 (tol = 1.000e-09) r (rel) = 1.419e-01 (tol = 1.000e-05)
#   Newton iteration 5: r (abs) = 1.665e-04 (tol = 1.000e-09) r (rel) = 1.980e-02 (tol = 1.000e-05)
#   Newton iteration 6: r (abs) = 4.152e-06 (tol = 1.000e-09) r (rel) = 4.937e-04 (tol = 1.000e-05)
#   Newton iteration 7: r (abs) = 5.171e-09 (tol = 1.000e-09) r (rel) = 6.149e-07 (tol = 1.000e-05)
#   Newton solver finished in 7 iterations and 7 linear solver iterations.
# *** Warning: Degree of exact solution may be inadequate for accurate result in errornorm.
# *** Warning: Degree of exact solution may be inadequate for accurate result in errornorm.
# Error:  0.4274902828731505
# Solving linear variational problem.
# No Jacobian form specified for nonlinear variational problem.
# Differentiating residual form F to obtain Jacobian J = F'.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 1.439e-05 (tol = 1.000e-09) r (rel) = 1.000e+00 (tol = 1.000e-05)
#   Newton iteration 1: r (abs) = 2.645e-10 (tol = 1.000e-09) r (rel) = 1.837e-05 (tol = 1.000e-05)
#   Newton solver finished in 1 iterations and 1 linear solver iterations.
# *** Warning: Degree of exact solution may be inadequate for accurate result in errornorm.
# *** Warning: Degree of exact solution may be inadequate for accurate result in errornorm.
# Error:  6.351552668898257e-05
# ---------- Dead Load Iteration: 30 ------------
# Load:  4.102999999999997
# Solving linear variational problem.
# No Jacobian form specified for nonlinear variational problem.
# Differentiating residual form F to obtain Jacobian J = F'.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 8.410e-03 (tol = 1.000e-09) r (rel) = 1.000e+00 (tol = 1.000e-05)
#   Newton iteration 1: r (abs) = 4.303e-03 (tol = 1.000e-09) r (rel) = 5.116e-01 (tol = 1.000e-05)
#   Newton iteration 2: r (abs) = 9.332e-05 (tol = 1.000e-09) r (rel) = 1.110e-02 (tol = 1.000e-05)
#   Newton iteration 3: r (abs) = 1.532e-06 (tol = 1.000e-09) r (rel) = 1.822e-04 (tol = 1.000e-05)
#   Newton iteration 4: r (abs) = 2.147e-10 (tol = 1.000e-09) r (rel) = 2.553e-08 (tol = 1.000e-05)
#   Newton solver finished in 4 iterations and 4 linear solver iterations.
# *** Warning: Degree of exact solution may be inadequate for accurate result in errornorm.
# *** Warning: Degree of exact solution may be inadequate for accurate result in errornorm.
# Error:  0.2295242040179418
# Solving linear variational problem.
# No Jacobian form specified for nonlinear variational problem.
# Differentiating residual form F to obtain Jacobian J = F'.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 9.038e-06 (tol = 1.000e-09) r (rel) = 1.000e+00 (tol = 1.000e-05)
#   Newton iteration 1: r (abs) = 8.559e-07 (tol = 1.000e-09) r (rel) = 9.469e-02 (tol = 1.000e-05)
#   Newton iteration 2: r (abs) = 3.884e-10 (tol = 1.000e-09) r (rel) = 4.298e-05 (tol = 1.000e-05)
#   Newton solver finished in 2 iterations and 2 linear solver iterations.
# *** Warning: Degree of exact solution may be inadequate for accurate result in errornorm.
# *** Warning: Degree of exact solution may be inadequate for accurate result in errornorm.
# Error:  0.00354843590742626
# Solving linear variational problem.
# No Jacobian form specified for nonlinear variational problem.
# Differentiating residual form F to obtain Jacobian J = F'.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 6.503e-08 (tol = 1.000e-09) r (rel) = 1.000e+00 (tol = 1.000e-05)
#   Newton iteration 1: r (abs) = 6.047e-08 (tol = 1.000e-09) r (rel) = 9.300e-01 (tol = 1.000e-05)
#   Newton iteration 2: r (abs) = 1.700e-13 (tol = 1.000e-09) r (rel) = 2.614e-06 (tol = 1.000e-05)
#   Newton solver finished in 2 iterations and 2 linear solver iterations.
# *** Warning: Degree of exact solution may be inadequate for accurate result in errornorm.
# *** Warning: Degree of exact solution may be inadequate for accurate result in errornorm.
# Error:  0.0009621310756452584
# ---------- Dead Load Iteration: 31 ------------
# Load:  4.202999999999997
# Solving linear variational problem.
# No Jacobian form specified for nonlinear variational problem.
# Differentiating residual form F to obtain Jacobian J = F'.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 8.410e-03 (tol = 1.000e-09) r (rel) = 1.000e+00 (tol = 1.000e-05)
#   Newton iteration 1: r (abs) = 2.285e-03 (tol = 1.000e-09) r (rel) = 2.717e-01 (tol = 1.000e-05)
#   Newton iteration 2: r (abs) = 2.026e-05 (tol = 1.000e-09) r (rel) = 2.408e-03 (tol = 1.000e-05)
#   Newton iteration 3: r (abs) = 4.528e-08 (tol = 1.000e-09) r (rel) = 5.384e-06 (tol = 1.000e-05)
#   Newton solver finished in 3 iterations and 3 linear solver iterations.
# *** Warning: Degree of exact solution may be inadequate for accurate result in errornorm.
# *** Warning: Degree of exact solution may be inadequate for accurate result in errornorm.
# Error:  0.18497862982049204
# Solving linear variational problem.
# No Jacobian form specified for nonlinear variational problem.
# Differentiating residual form F to obtain Jacobian J = F'.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 7.836e-06 (tol = 1.000e-09) r (rel) = 1.000e+00 (tol = 1.000e-05)
#   Newton iteration 1: r (abs) = 2.775e-06 (tol = 1.000e-09) r (rel) = 3.541e-01 (tol = 1.000e-05)
#   Newton iteration 2: r (abs) = 2.512e-09 (tol = 1.000e-09) r (rel) = 3.206e-04 (tol = 1.000e-05)
#   Newton iteration 3: r (abs) = 2.634e-07 (tol = 1.000e-09) r (rel) = 3.361e-02 (tol = 1.000e-05)
#   Newton iteration 4: r (abs) = 2.616e-08 (tol = 1.000e-09) r (rel) = 3.339e-03 (tol = 1.000e-05)
#   Newton iteration 5: r (abs) = 3.014e-08 (tol = 1.000e-09) r (rel) = 3.846e-03 (tol = 1.000e-05)
#   Newton iteration 6: r (abs) = 3.540e-10 (tol = 1.000e-09) r (rel) = 4.518e-05 (tol = 1.000e-05)
#   Newton solver finished in 6 iterations and 6 linear solver iterations.
# *** Warning: Degree of exact solution may be inadequate for accurate result in errornorm.
# *** Warning: Degree of exact solution may be inadequate for accurate result in errornorm.
# Error:  0.004654874492699526
# Solving linear variational problem.
# No Jacobian form specified for nonlinear variational problem.
# ...
#   Newton solver finished in 2 iterations and 2 linear solver iterations.
# *** Warning: Degree of exact solution may be inadequate for accurate result in errornorm.
# *** Warning: Degree of exact solution may be inadequate for accurate result in errornorm.
# Error:  0.001373727509104739
# Solving linear variational problem.
# No Jacobian form specified for nonlinear variational problem.
# Differentiating residual form F to obtain Jacobian J = F'.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 2.949e-08 (tol = 1.000e-09) r (rel) = 1.000e+00 (tol = 1.000e-06)
#   Newton iteration 1: r (abs) = 7.602e-08 (tol = 1.000e-09) r (rel) = 2.578e+00 (tol = 1.000e-06)
#   Newton iteration 2: r (abs) = 1.768e-14 (tol = 1.000e-09) r (rel) = 5.996e-07 (tol = 1.000e-06)
#   Newton solver finished in 2 iterations and 2 linear solver iterations.
# *** Warning: Degree of exact solution may be inadequate for accurate result in errornorm.
# *** Warning: Degree of exact solution may be inadequate for accurate result in errornorm.
# Error:  0.0010258781416834814
# Solving linear variational problem.
# No Jacobian form specified for nonlinear variational problem.
# Differentiating residual form F to obtain Jacobian J = F'.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 2.203e-08 (tol = 1.000e-09) r (rel) = 1.000e+00 (tol = 1.000e-06)
#   Newton iteration 1: r (abs) = 4.237e-08 (tol = 1.000e-09) r (rel) = 1.923e+00 (tol = 1.000e-06)
#   Newton iteration 2: r (abs) = 8.838e-15 (tol = 1.000e-09) r (rel) = 4.012e-07 (tol = 1.000e-06)
#   Newton solver finished in 2 iterations and 2 linear solver iterations.
# *** Warning: Degree of exact solution may be inadequate for accurate result in errornorm.
# *** Warning: Degree of exact solution may be inadequate for accurate result in errornorm.
# Error:  0.0007659620789744388
# Solving linear variational problem.
# No Jacobian form specified for nonlinear variational problem.
# Differentiating residual form F to obtain Jacobian J = F'.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 1.644e-08 (tol = 1.000e-09) r (rel) = 1.000e+00 (tol = 1.000e-06)
#   Newton iteration 1: r (abs) = 2.362e-08 (tol = 1.000e-09) r (rel) = 1.437e+00 (tol = 1.000e-06)
#   Newton iteration 2: r (abs) = 7.475e-15 (tol = 1.000e-09) r (rel) = 4.546e-07 (tol = 1.000e-06)
#   Newton solver finished in 2 iterations and 2 linear solver iterations.
# *** Warning: Degree of exact solution may be inadequate for accurate result in errornorm.
# *** Warning: Degree of exact solution may be inadequate for accurate result in errornorm.
# Error:  0.0005719072224631012
# Solving linear variational problem.
# No Jacobian form specified for nonlinear variational problem.
# Differentiating residual form F to obtain Jacobian J = F'.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 1.228e-08 (tol = 1.000e-09) r (rel) = 1.000e+00 (tol = 1.000e-06)
#   Newton iteration 1: r (abs) = 1.317e-08 (tol = 1.000e-09) r (rel) = 1.072e+00 (tol = 1.000e-06)
#   Newton iteration 2: r (abs) = 7.363e-15 (tol = 1.000e-09) r (rel) = 5.996e-07 (tol = 1.000e-06)
#   Newton solver finished in 2 iterations and 2 linear solver iterations.
# *** Warning: Degree of exact solution may be inadequate for accurate result in errornorm.
# *** Warning: Degree of exact solution may be inadequate for accurate result in errornorm.
# Error:  0.0004270198153066019
# Solving linear variational problem.
# No Jacobian form specified for nonlinear variational problem.
# Differentiating residual form F to obtain Jacobian J = F'.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 9.168e-09 (tol = 1.000e-09) r (rel) = 1.000e+00 (tol = 1.000e-06)
#   Newton iteration 1: r (abs) = 7.342e-09 (tol = 1.000e-09) r (rel) = 8.008e-01 (tol = 1.000e-06)
#   Newton iteration 2: r (abs) = 7.410e-15 (tol = 1.000e-09) r (rel) = 8.083e-07 (tol = 1.000e-06)
#   Newton solver finished in 2 iterations and 2 linear solver iterations.
# *** Warning: Degree of exact solution may be inadequate for accurate result in errornorm.
# *** Warning: Degree of exact solution may be inadequate for accurate result in errornorm.
# Error:  0.0003188321574457122
# Solving linear variational problem.
# No Jacobian form specified for nonlinear variational problem.
# Differentiating residual form F to obtain Jacobian J = F'.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 6.845e-09 (tol = 1.000e-09) r (rel) = 1.000e+00 (tol = 1.000e-06)
#   Newton iteration 1: r (abs) = 4.093e-09 (tol = 1.000e-09) r (rel) = 5.979e-01 (tol = 1.000e-06)
#   Newton iteration 2: r (abs) = 7.321e-15 (tol = 1.000e-09) r (rel) = 1.070e-06 (tol = 1.000e-06)
#   Newton solver finished in 2 iterations and 2 linear solver iterations.
# *** Warning: Degree of exact solution may be inadequate for accurate result in errornorm.
# *** Warning: Degree of exact solution may be inadequate for accurate result in errornorm.
# Error:  0.00023805781115825462
# Solving linear variational problem.
# No Jacobian form specified for nonlinear variational problem.
# Differentiating residual form F to obtain Jacobian J = F'.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 5.111e-09 (tol = 1.000e-09) r (rel) = 1.000e+00 (tol = 1.000e-06)
#   Newton iteration 1: r (abs) = 2.282e-09 (tol = 1.000e-09) r (rel) = 4.464e-01 (tol = 1.000e-06)
#   Newton iteration 2: r (abs) = 7.416e-15 (tol = 1.000e-09) r (rel) = 1.451e-06 (tol = 1.000e-06)
#   Newton solver finished in 2 iterations and 2 linear solver iterations.
# *** Warning: Degree of exact solution may be inadequate for accurate result in errornorm.
# *** Warning: Degree of exact solution may be inadequate for accurate result in errornorm.
# Error:  0.00017774554473917587
# Solving linear variational problem.
# No Jacobian form specified for nonlinear variational problem.
# Differentiating residual form F to obtain Jacobian J = F'.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 3.816e-09 (tol = 1.000e-09) r (rel) = 1.000e+00 (tol = 1.000e-06)
#   Newton iteration 1: r (abs) = 1.272e-09 (tol = 1.000e-09) r (rel) = 3.333e-01 (tol = 1.000e-06)
#   Newton iteration 2: r (abs) = 7.325e-15 (tol = 1.000e-09) r (rel) = 1.920e-06 (tol = 1.000e-06)
#   Newton solver finished in 2 iterations and 2 linear solver iterations.
# *** Warning: Degree of exact solution may be inadequate for accurate result in errornorm.
# *** Warning: Degree of exact solution may be inadequate for accurate result in errornorm.
# Error:  0.00013271551080458544
# Solving linear variational problem.
# No Jacobian form specified for nonlinear variational problem.
# Differentiating residual form F to obtain Jacobian J = F'.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 2.849e-09 (tol = 1.000e-09) r (rel) = 1.000e+00 (tol = 1.000e-06)
#   Newton iteration 1: r (abs) = 7.092e-10 (tol = 1.000e-09) r (rel) = 2.489e-01 (tol = 1.000e-06)
#   Newton solver finished in 1 iterations and 1 linear solver iterations.
# *** Warning: Degree of exact solution may be inadequate for accurate result in errornorm.
# *** Warning: Degree of exact solution may be inadequate for accurate result in errornorm.
# Error:  9.90931997711863e-05
# ---------- Voltage Iteration: 9 ------------
# Solving linear variational problem.
# No Jacobian form specified for nonlinear variational problem.
# Differentiating residual form F to obtain Jacobian J = F'.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 2.647e-06 (tol = 1.000e-09) r (rel) = 1.000e+00 (tol = 1.000e-06)
#   Newton iteration 1: r (abs) = 1.541e-03 (tol = 1.000e-09) r (rel) = 5.822e+02 (tol = 1.000e-06)
#   Newton iteration 2: r (abs) = 6.095e-06 (tol = 1.000e-09) r (rel) = 2.303e+00 (tol = 1.000e-06)
#   Newton iteration 3: r (abs) = 2.357e-09 (tol = 1.000e-09) r (rel) = 8.903e-04 (tol = 1.000e-06)
#   Newton iteration 4: r (abs) = 9.613e-08 (tol = 1.000e-09) r (rel) = 3.632e-02 (tol = 1.000e-06)
#   Newton iteration 5: r (abs) = 1.444e-10 (tol = 1.000e-09) r (rel) = 5.456e-05 (tol = 1.000e-06)
#   Newton solver finished in 5 iterations and 5 linear solver iterations.
# *** Warning: Degree of exact solution may be inadequate for accurate result in errornorm.
# *** Warning: Degree of exact solution may be inadequate for accurate result in errornorm.
# Error:  0.14418772300145336
# Solving linear variational problem.
# No Jacobian form specified for nonlinear variational problem.
# Differentiating residual form F to obtain Jacobian J = F'.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 3.173e-06 (tol = 1.000e-09) r (rel) = 1.000e+00 (tol = 1.000e-06)
#   Newton iteration 1: r (abs) = 9.310e-04 (tol = 1.000e-09) r (rel) = 2.934e+02 (tol = 1.000e-06)
#   Newton iteration 2: r (abs) = 2.267e-06 (tol = 1.000e-09) r (rel) = 7.146e-01 (tol = 1.000e-06)
#   Newton iteration 3: r (abs) = 3.255e-10 (tol = 1.000e-09) r (rel) = 1.026e-04 (tol = 1.000e-06)
#   Newton solver finished in 3 iterations and 3 linear solver iterations.
# *** Warning: Degree of exact solution may be inadequate for accurate result in errornorm.
# *** Warning: Degree of exact solution may be inadequate for accurate result in errornorm.
# Error:  0.11317267570943011
# Solving linear variational problem.
# No Jacobian form specified for nonlinear variational problem.
# Differentiating residual form F to obtain Jacobian J = F'.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 2.517e-06 (tol = 1.000e-09) r (rel) = 1.000e+00 (tol = 1.000e-06)
#   Newton iteration 1: r (abs) = 5.686e-04 (tol = 1.000e-09) r (rel) = 2.259e+02 (tol = 1.000e-06)
#   Newton iteration 2: r (abs) = 8.556e-07 (tol = 1.000e-09) r (rel) = 3.399e-01 (tol = 1.000e-06)
#   Newton iteration 3: r (abs) = 4.991e-10 (tol = 1.000e-09) r (rel) = 1.983e-04 (tol = 1.000e-06)
#   Newton solver finished in 3 iterations and 3 linear solver iterations.
# *** Warning: Degree of exact solution may be inadequate for accurate result in errornorm.
# *** Warning: Degree of exact solution may be inadequate for accurate result in errornorm.
# Error:  0.08847563167453192
# Solving linear variational problem.
# No Jacobian form specified for nonlinear variational problem.
# Differentiating residual form F to obtain Jacobian J = F'.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 1.952e-06 (tol = 1.000e-09) r (rel) = 1.000e+00 (tol = 1.000e-06)
#   Newton iteration 1: r (abs) = 3.437e-04 (tol = 1.000e-09) r (rel) = 1.761e+02 (tol = 1.000e-06)
#   Newton iteration 2: r (abs) = 3.148e-07 (tol = 1.000e-09) r (rel) = 1.613e-01 (tol = 1.000e-06)
#   Newton iteration 3: r (abs) = 1.003e-09 (tol = 1.000e-09) r (rel) = 5.139e-04 (tol = 1.000e-06)
#   Newton iteration 4: r (abs) = 1.856e-08 (tol = 1.000e-09) r (rel) = 9.507e-03 (tol = 1.000e-06)
#   Newton iteration 5: r (abs) = 6.474e-13 (tol = 1.000e-09) r (rel) = 3.317e-07 (tol = 1.000e-06)
#   Newton solver finished in 5 iterations and 5 linear solver iterations.
# *** Warning: Degree of exact solution may be inadequate for accurate result in errornorm.
# *** Warning: Degree of exact solution may be inadequate for accurate result in errornorm.
# Error:  0.06851592608703938
# Solving linear variational problem.
# No Jacobian form specified for nonlinear variational problem.
# Differentiating residual form F to obtain Jacobian J = F'.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 1.522e-06 (tol = 1.000e-09) r (rel) = 1.000e+00 (tol = 1.000e-06)
#   Newton iteration 1: r (abs) = 2.082e-04 (tol = 1.000e-09) r (rel) = 1.368e+02 (tol = 1.000e-06)
#   Newton iteration 2: r (abs) = 1.160e-07 (tol = 1.000e-09) r (rel) = 7.623e-02 (tol = 1.000e-06)
#   Newton iteration 3: r (abs) = 2.312e-08 (tol = 1.000e-09) r (rel) = 1.520e-02 (tol = 1.000e-06)
#   Newton iteration 4: r (abs) = 7.678e-08 (tol = 1.000e-09) r (rel) = 5.046e-02 (tol = 1.000e-06)
#   Newton iteration 5: r (abs) = 3.391e-09 (tol = 1.000e-09) r (rel) = 2.229e-03 (tol = 1.000e-06)
#   Newton iteration 6: r (abs) = 5.944e-10 (tol = 1.000e-09) r (rel) = 3.906e-04 (tol = 1.000e-06)
#   Newton solver finished in 6 iterations and 6 linear solver iterations.
# *** Warning: Degree of exact solution may be inadequate for accurate result in errornorm.
# *** Warning: Degree of exact solution may be inadequate for accurate result in errornorm.
# Error:  0.053987099760824046
# Solving linear variational problem.
# No Jacobian form specified for nonlinear variational problem.
# Differentiating residual form F to obtain Jacobian J = F'.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 1.193e-06 (tol = 1.000e-09) r (rel) = 1.000e+00 (tol = 1.000e-06)
#   Newton iteration 1: r (abs) = 1.317e-04 (tol = 1.000e-09) r (rel) = 1.104e+02 (tol = 1.000e-06)
#   Newton iteration 2: r (abs) = 4.656e-08 (tol = 1.000e-09) r (rel) = 3.902e-02 (tol = 1.000e-06)
#   Newton iteration 3: r (abs) = 3.124e-08 (tol = 1.000e-09) r (rel) = 2.618e-02 (tol = 1.000e-06)
#   Newton iteration 4: r (abs) = 1.811e-08 (tol = 1.000e-09) r (rel) = 1.518e-02 (tol = 1.000e-06)
#   Newton iteration 5: r (abs) = 6.096e-10 (tol = 1.000e-09) r (rel) = 5.109e-04 (tol = 1.000e-06)
#   Newton solver finished in 5 iterations and 5 linear solver iterations.
# *** Warning: Degree of exact solution may be inadequate for accurate result in errornorm.
# *** Warning: Degree of exact solution may be inadequate for accurate result in errornorm.
# Error:  0.04244026530028309
# Solving linear variational problem.
# No Jacobian form specified for nonlinear variational problem.
# Differentiating residual form F to obtain Jacobian J = F'.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 9.416e-07 (tol = 1.000e-09) r (rel) = 1.000e+00 (tol = 1.000e-06)
#   Newton iteration 1: r (abs) = 8.071e-05 (tol = 1.000e-09) r (rel) = 8.572e+01 (tol = 1.000e-06)
#   Newton iteration 2: r (abs) = 1.751e-08 (tol = 1.000e-09) r (rel) = 1.859e-02 (tol = 1.000e-06)
#   Newton iteration 3: r (abs) = 7.192e-12 (tol = 1.000e-09) r (rel) = 7.638e-06 (tol = 1.000e-06)
#   Newton solver finished in 3 iterations and 3 linear solver iterations.
# *** Warning: Degree of exact solution may be inadequate for accurate result in errornorm.
# *** Warning: Degree of exact solution may be inadequate for accurate result in errornorm.
# Error:  0.03343033209516932
# Solving linear variational problem.
# No Jacobian form specified for nonlinear variational problem.
# Differentiating residual form F to obtain Jacobian J = F'.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 7.395e-07 (tol = 1.000e-09) r (rel) = 1.000e+00 (tol = 1.000e-06)
#   Newton iteration 1: r (abs) = 5.017e-05 (tol = 1.000e-09) r (rel) = 6.785e+01 (tol = 1.000e-06)
#   Newton iteration 2: r (abs) = 6.771e-09 (tol = 1.000e-09) r (rel) = 9.157e-03 (tol = 1.000e-06)
#   Newton iteration 3: r (abs) = 2.037e-10 (tol = 1.000e-09) r (rel) = 2.755e-04 (tol = 1.000e-06)
#   Newton solver finished in 3 iterations and 3 linear solver iterations.
# *** Warning: Degree of exact solution may be inadequate for accurate result in errornorm.
# *** Warning: Degree of exact solution may be inadequate for accurate result in errornorm.
# Error:  0.02629959338345986
# Solving linear variational problem.
# No Jacobian form specified for nonlinear variational problem.
# Differentiating residual form F to obtain Jacobian J = F'.
# Solving nonlinear variational problem.
#   Newton iteration 0: r (abs) = 5.831e-07 (tol = 1.000e-09) r (rel) = 1.000e+00 (tol = 1.000e-06)
#   Newton iteration 1: r (abs) = 3.093e-05 (tol = 1.000e-09) r (rel) = 5.305e+01 (tol = 1.000e-06)
#   Newton iteration 2: r (abs) = 2.575e-09 (tol = 1.000e-09) r (rel) = 4.417e-03 (tol = 1.000e-06)
#   Newton iteration 3: r (abs) = 2.793e-11 (tol = 1.000e-09) r (rel) = 4.790e-05 (tol = 1.000e-06)
#   Newton solver finished in 3 iterations and 3 linear solver iterations.
# *** Warning: Degree of exact solution may be inadequate for accurate result in errornorm.
# *** Warning: Degree of exact solution may be inadequate for accurate result in errornorm.
# Error:  0.020712895572430445
# Solving linear variational problem.
